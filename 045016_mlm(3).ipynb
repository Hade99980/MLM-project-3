# %% [markdown]
# Deepankar Vashishta 045016
#
# Segmentation of Consumer Data using Supervised Machine Learning
#
# Objective: The goal is to segment consumers based on their similar characteristics, behavior, and get on a single decison.
#
# Approach:We will do decision tree and ranodm forest and do the comparison of that for the future managerial implications.
#
# Data: The dataset contains details of customers, including their marital status, income, number of items purchased, and types of items purchased.
#
# Preprocessing: Data Shape: The dataset has dimensions (66708, 12). Features for Clustering: We'll consider features such as Ratings, Reviews, and Original Price. Determination of Segment or Cluster Characteristics
#
# Interpretation: Once we have the optimal number of clusters, we'll analyze the characteristics of each segment. This involves understanding the common traits, preferences, and behaviors of customers within each cluster. We will analyze non-categorical data like reviews, prices, and ratings.
#
# Insights: We'll provide insights into the distinct features of each segment, which can guide Ratings, Reviews, and Prices.
#
# Index Variable(s): These are the identifiers for each record in your dataset. They are typically used for referencing specific rows.
#
# Categorical Variables or Features (CV): These variables represent categories or groups. Let’s further explore the subtypes:
#
# Variables with Nominal Categories (CNV): These are categorical features where the order of categories doesn’t matter. Examples from your dataset include: BrandName, Category, Individual_category.
#
# Variables with Ordinal Categories (COV): These are categorical features where the order of categories matters. Examples from your dataset include: SizeOption.
#
# Non-Categorical Variables or Features: These variables are numeric or continuous. They do not fall into the categorical category. Examples from your dataset include: Product_id, OriginalPrice, Ratings, Reviews, DiscountPrice, DiscountOffer.
#
# Descriptive Statistics: Categorical Variables or Features Description of Variables:
#
# Index Variable(s): Cluster_number
# Outcome Variable or Feature (OV): DiscountOffer
# Input Variables or Features having Categories (ICV):
# Input Variables or Features having Nominal Categories (ICNV):
# BrandName
# Category
# Individual_category
# category_by_Gender
# Input Variables or Features having Ordinal Categories (ICOV):
# SizeOption
# Input Non-Categorical Variables or Features (INCV):
# OriginalPrice (in Rs)
# Ratings
# Reviews
# DiscountPrice (in Rs) Missing Data Statistics: Records There are no missing values in any of the records (rows). All records have complete data.
# Missing Data Statistics: Categorical Variables or Features There are no missing values in any of the categorical variables (columns)
#
# Boxplot Visualization: The code creates a boxplot to visualize the distribution of these features. Each feature has its own boxplot, allowing us to understand their central tendency, spread, and presence of outliers.
#
# Boxplot Interpretation: ‘OriginalPrice (in Rs)’: The boxplot for this feature shows a wide range of values. There are several outliers above the upper whisker, indicating that some products have significantly higher prices than the majority.
#
# Ratings’: The ratings feature exhibits one outlier. Most ratings seem to be clustered around a specific value.
#
# ‘Reviews’: The reviews feature also has an outlier. Data is concentrated around a median value.
#
# ‘DiscountPrice (in Rs)’ and ‘DiscountOffer’: Both features show no outliers. Their data spread is relatively small compared to ‘OriginalPrice’.
#
# Selection of Input and output Variables
#
# The objective is to select input variables for further analysis from the preprocessed DataFrame the selected variables are BrandName_y', 'Category_y', 'Individual_category_y', 'Description_y', 'SizeOption_y', 'Product_id', 'OriginalPrice (in Rs)', 'Ratings', 'DiscountPrice (in Rs)','Reviews','DiscountOffer' and the output variable is Gender_category.
#
# Decision Tree Importance & Feature Category_y: This feature has the highest importance, with a score of 1.0. It suggests that the category of the product (perhaps in a dataset) is the most influential in whatever analysis or prediction task was performed. For example, if you're predicting sales, the category of a product might be the strongest predictor of its sales volume.
#
# BrandName_y: This feature has an importance score of 0.0, indicating that it does not contribute to the analysis. It suggests that the brand name associated with the product does not significantly affect the outcome being studied.
#
# Individual_category_y, Description_y, SizeOption_y, Product_id, OriginalPrice (in Rs), Ratings, DiscountPrice (in Rs), Reviews, DiscountOffer: Similar to BrandName_y, all these features have importance scores of 0.0. This implies that none of these features contribute significantly to the analysis or prediction task at hand.
#
# Analysis of the decision tree:
#
# Root Node: The root node represents the initial decision point. In this case, it evaluates the feature “Category y.” If “Category y” is less than or equal to 0.5, the tree proceeds to the left branch; otherwise, it takes the right branch. First Level: If “Category y” is less than or equal to 0.5: The left branch leads to a leaf node with a class label of 1.0 (indicating a positive outcome). The gini impurity at this node is 0, meaning all samples belong to the same class. The total number of samples here is 67,708. If “Category y” is greater than 0.5 but less than or equal to 6.5: The right branch further evaluates “Category y.” If “Category y” is less than or equal to 5.5: Another leaf node with a class label of 1.0 is reached. The gini impurity remains low (0.386). The total number of samples here is 57,334. If “Category y” is greater than 5.5: Yet another leaf node with a class label of 0 (negative outcome) is encountered. The gini impurity here is 0.479. The total number of samples is 37,955. Further Levels: The tree continues to branch based on additional conditions, but the provided snippet doesn’t reveal the subsequent levels. Each leaf node represents a final decision or outcome. In summary, this decision tree aims to classify samples based on the “Category y” feature. It splits the data into different classes by recursively evaluating conditions. The gini impurity measures the impurity of the class distribution at each node.
#
# Random Forest
#
# The feature importances suggest that the most influential feature for predicting the target is 'Category_y', contributing approximately 47.7% to the model's decision-making process. 'SizeOption_y' follows as the second most important feature, accounting for around 15.9% of the predictive power. Other features such as 'Individual_category_y' and 'Description_y' also hold significant importance, while features like 'DiscountPrice (in Rs)' and 'DiscountOffer' contribute minimally to the model's predictions. This analysis highlights the key drivers behind the model's decision-making process, aiding in understanding the underlying patterns in the data.
# Testing of the Dataset
#
# The confusion matrix indicates that the model made no false predictions for either class, with all instances of class 0 and class 1 correctly classified. Consequently, precision, recall, and F1-score are all perfect (1.00) for both classes, highlighting the model's exceptional performance. The high accuracy of 1.00 further confirms the model's ability to accurately classify instances. This outcome suggests that the model has learned the underlying patterns in the data extremely well, resulting in flawless classification across both classes.
#
# Confusion Matrix Overview:
# 	The image shows a confusion matrix for a decision tree model.
# 	This matrix evaluates the performance of the model in a binary classification task.
# 	It consists of a 2x2 grid representing the following:
# 	True Negatives (TN): The number of correctly predicted negative instances (class 0).
# 	True Positives (TP): The number of correctly predicted positive instances (class 1).
# 	False Positives (FP): Instances incorrectly predicted as positive.
# 	False Negatives (FN): Instances incorrectly predicted as negative.
# 2.	Matrix Details:
# The X-axis represents the predicted labels, with categories 0 and 1.
# 	The Y-axis represents the true labels, also with categories 0 and 1.
# 	The values in each cell indicate the count of instances falling into that category.
# 	Here’s the breakdown:
# 	True Negatives (TN): 24346
# 	True Positives (TP): 42362
# 	False Positives (FP): 0
# 	False Negatives (FN): 0
# 3.	Model Performance:
#   The decision tree model seems to have performed exceptionally well:
#   No false positives or false negatives.
# 	Perfectly classified the data with high precision and recall.
# 	Perfectly classified the data with high precision and recall.
#
# Random Forest Classifier
# 1. Decision Tree Structure:The tree follows a hierarchical structure where nodes represent split conditions based on features, guiding the classification process down the branches until reaching leaf nodes, which provide the final classification.
#
# 2. Feature Importance: Features like 'Reviews', 'BrandName_y', and 'Individual_category_y' are utilized for decision-making, suggesting their significance in distinguishing between classes.
#
# 3Sample Distribution: The 'value' parameter within each node shows the distribution of classes. For instance, [0.365, 0.635] implies that within that node, 36.5% of samples belong to class 0 and 63.5% belong to class 1.
#
# 4. Node Conditions: Conditions like 'Reviews <= 33.5' or 'Individual_category_y <= 74.5' serve as decision rules. If true, the model follows the left branch; otherwise, it takes the right branch.
#
# 5. Analysis: The tree appears to make decisions primarily based on 'Reviews', 'BrandName_y', 'Individual_category_y', and 'Category_y'. Split conditions help partition the data into subsets where class distributions become more distinct, aiding accurate classification.
#
# 6. Model Complexity: The tree seems to have multiple levels of branching, indicating a relatively complex model. While this complexity may capture intricate patterns, it also increases the risk of overfitting, especially if the tree continues to grow excessively.
#
# 7. Class Imbalance In some nodes, there's a notable class imbalance, with one class dominating the other. For example, in the last node with 'Individual_category_y <= 78.5', class 1 comprises 79.4% of the samples, indicating a potential bias towards that class in this subset of data.
#
# Comparison Between Decision tree and random forest.
# 1.	Random Forest Model:
# 	Accuracy: The accuracy of the Random Forest model is 88%.
# 	Precision:
# 	For class 0 (negative instances), the precision is 100%.
# 	For class 1 (positive instances), the precision is 84%.
# 	Recall:
# 	For class 0, the recall is 68%.
# 	For class 1, the recall is 100%.
# 	F1-score:
# 	The F1-score for class 0 is 0.81.
#   The F1-score for class 1 is 0.92.
# 2.	Decision Tree Model:
# 	Accuracy: The accuracy of the Decision Tree model is 100%.
# 	Precision:
# 	For class 0, the precision is 100%.
# 	For class 1, the precision is 100%.
# 	Recall:
# 	For class 0, the recall is 100%.
# 	For class 1, the recall is 100%.
# 	F1-score:
# 	The F1-score for class 0 is 1.00.
# 	The F1-score for class 1 is 1.00.
# 3.	Comparison:
# 	The Decision Tree model has achieved perfect classification on the given data, with no false positives or false negatives.
# 	The Random Forest model, while still performing well, has a slightly lower recall for class 0 due to its trade-off with precision.
#
# Managerial Implications
#
# 1.	Decision Tree Model:
#
# o	Advantages:
# 	Perfect Classification: The Decision Tree model achieved 100% accuracy, correctly classifying all instances in the dataset.
#
# 	Interpretability: Decision trees are easy to understand and visualize, making them suitable for explaining model decisions to stakeholders.
#
# 	Low Computational Cost: Decision trees are computationally efficient during training and prediction.
#
# o	Implications:
# 	Risk of Overfitting: While the model performed well on the given data, theres a risk of overfitting. Decision trees tend to create complex rules that may not generalize well to unseen data.
#
# 	Sensitive to Data Variations: Small changes in the dataset can lead to different tree structures, affecting model performance.
#
# 	Lack of Robustness: Decision trees are sensitive to outliers and noise in the data.
#
# o	Recommendations:
# 	Consider pruning the tree to prevent overfitting.
# 	Validate the model on an independent test set to assess generalization performance.
# 	Monitor model performance over time to detect any significant changes.
#
# 2.	Random Forest Model:
# o	Advantages:
# 	Ensemble Approach: Random Forest combines multiple decision trees, reducing overfitting and improving robustness.
#
# 	Higher Generalization: Random Forest tends to perform well on unseen data due to its ensemble nature.
#
# 	Feature Importance: Random Forest provides feature importance scores, aiding in feature selection.
# o	Implications:
#
# 	Increased Complexity: Random Forest involves multiple trees, which can be harder to interpret than a single decision tree.
#
# 	Resource Intensive: Training a Random Forest requires more computational resources.
#
# 	Hyperparameter Tuning: Proper tuning of hyperparameters (e.g., number of trees, depth) is crucial.

# %%
## Data Visualization Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree
import graphviz
from IPython.display import display
from collections import Counter

## Data Preprocessing Libraries
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.metrics import f1_score
from sklearn.tree import export_text

from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
## Machine Learning Models and Evaluation Metrics
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.validation import column_or_1d
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_recall_fscore_support
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.tree import export_graphviz

# %%
df = pd.read_csv('df_MFC.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  cluster_number  Product_id  BrandName  Category  \
# 0           0               0     2296012        648         0
# 1           1               1    13780156        428         0
# 2           2               2    11895958        648         6
# 3           3               0     4335679        892         3
# 4           4               2    11690882        648         7
#
#    Individual_category  category_by_Gender  Description  \
# 0                   24                   0        41046
# 1                   75                   0        28448
# 2                   56                   0        41089
# 3                   53                   1        58327
# 4                   79                   1        43301
#
#    OriginalPrice (in Rs)  SizeOption  Ratings  Reviews  DiscountPrice (in Rs)  \
# 0                   1499         131      3.9      999                    317
# 1                   1149         969      4.0      999                    443
# ...

# %%
df.info() # Dataframe Information (Provide Information on Missing Data)
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66708 entries, 0 to 66707
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             66708 non-null  int64
#  1   cluster_number         66708 non-null  int64
#  2   Product_id             66708 non-null  int64
#  3   BrandName              66708 non-null  int64
#  4   Category               66708 non-null  int64
#  5   Individual_category    66708 non-null  int64
#  6   category_by_Gender     66708 non-null  int64
#  7   Description            66708 non-null  int64
#  8   OriginalPrice (in Rs)  66708 non-null  int64
#  9   SizeOption             66708 non-null  int64
#  10  Ratings                66708 non-null  float64
#  11  Reviews                66708 non-null  int64
#  12  DiscountPrice (in Rs)  66708 non-null  int64
#  13  DiscountOffer          66708 non-null  int64
# ...

# %%
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# Unnamed: 0               0
# cluster_number           0
# Product_id               0
# BrandName                0
# Category                 0
# Individual_category      0
# category_by_Gender       0
# Description              0
# OriginalPrice (in Rs)    0
# SizeOption               0
# Ratings                  0
# Reviews                  0
# DiscountPrice (in Rs)    0
# DiscountOffer            0
# cluster                  0
# dtype: int64

# %%
df_cat=df[['BrandName', 'Category', 'Individual_category', 'category_by_Gender',
       'Description', 'SizeOption']]
df_cat
# Out:
#        BrandName  Category  Individual_category  category_by_Gender  \
# 0            648         0                   24                   0
# 1            428         0                   75                   0
# 2            648         6                   56                   0
# 3            892         3                   53                   1
# 4            648         7                   79                   1
# ...          ...       ...                  ...                 ...
# 66703        511         1                   28                   0
# 66704        328         1                   28                   0
# 66705        893         1                   28                   0
# 66706        820         1                   28                   0
# 66707        182         1                   37                   0
#
#        Description  SizeOption
# 0            41046         131
# 1            28448         969
# 2            41089         810
# ...

# %%
df_non_cat=df[['Product_id', 'OriginalPrice (in Rs)', 'Ratings', 'Reviews',
       'DiscountPrice (in Rs)', 'DiscountOffer']]
df_non_cat
# Out:
#        Product_id  OriginalPrice (in Rs)  Ratings  Reviews  \
# 0         2296012                   1499      3.9      999
# 1        13780156                   1149      4.0      999
# 2        11895958                   1399      4.3      999
# 3         4335679                   1295      4.2      999
# 4        11690882                    599      4.2      999
# ...           ...                    ...      ...      ...
# 66703    13017776                   2999      4.6       33
# 66704    14604098                   3299      4.3       33
# 66705     7127587                   3398      3.8       33
# 66706    14051584                   3499      4.3       33
# 66707    10263333                   3590      3.8       33
#
#        DiscountPrice (in Rs)  DiscountOffer
# 0                        317             32
# 1                        443             50
# 2                        459             37
# 3                        393             47
# ...

# %%
variable_missing_data = df_cat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# BrandName              0
# Category               0
# Individual_category    0
# category_by_Gender     0
# Description            0
# SizeOption             0
# dtype: int64

# %%
variable_missing_data = df_non_cat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# Product_id               0
# OriginalPrice (in Rs)    0
# Ratings                  0
# Reviews                  0
# DiscountPrice (in Rs)    0
# DiscountOffer            0
# dtype: int64

# %%
df_cat_mdt_code = df_cat.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
# Create DataFrame with index and column names
df_cat_code_oe = pd.DataFrame(oe_fit, index=df_cat_mdt_code.index, columns=df_cat_mdt_code.columns)
#df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True); df_cat_mdt_code_oe
# Out:
#        BrandName_x  Category_x  Individual_category_x  category_by_Gender_x  \
# 0              648           0                     24                     0
# 1              428           0                     75                     0
# 2              648           6                     56                     0
# 3              892           3                     53                     1
# 4              648           7                     79                     1
# ...            ...         ...                    ...                   ...
# 66703          511           1                     28                     0
# 66704          328           1                     28                     0
# 66705          893           1                     28                     0
# 66706          820           1                     28                     0
# 66707          182           1                     37                     0
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_non_cat is your DataFrame containing the required columns
# If not, replace this with your DataFrame name
# Load your data into df_non_cat

# Select the columns for boxplot
columns = ['OriginalPrice (in Rs)', 'Ratings', 'Reviews', 'DiscountPrice (in Rs)', 'DiscountOffer']

# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_non_cat[columns])
plt.title('Boxplot of Features')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
df_non_cat_mdt= df_non_cat[['OriginalPrice (in Rs)', 'Ratings', 'Reviews', 'DiscountPrice (in Rs)', 'DiscountOffer']].copy()

# %%
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_non_cat_mdt)
df_non_cat_minmax_norm = pd.DataFrame(mms_fit,index=df_cat_mdt_code.index,columns=df_non_cat_mdt.columns+'_mn'); df_non_cat_minmax_norm
df_non_cat_mdt_mmn = pd.merge(df_non_cat, df_non_cat_minmax_norm, left_index=True, right_index=True); df_non_cat_mdt_mmn
# Out:
#        Product_id  OriginalPrice (in Rs)  Ratings  Reviews  \
# 0         2296012                   1499      3.9      999
# 1        13780156                   1149      4.0      999
# 2        11895958                   1399      4.3      999
# 3         4335679                   1295      4.2      999
# 4        11690882                    599      4.2      999
# ...           ...                    ...      ...      ...
# 66703    13017776                   2999      4.6       33
# 66704    14604098                   3299      4.3       33
# 66705     7127587                   3398      3.8       33
# 66706    14051584                   3499      4.3       33
# 66707    10263333                   3590      3.8       33
#
#        DiscountPrice (in Rs)  DiscountOffer  OriginalPrice (in Rs)_mn  \
# 0                        317             32                  0.068945
# 1                        443             50                  0.051331
# ...

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset
# Out:
#        BrandName_x  Category_x  Individual_category_x  category_by_Gender_x  \
# 0              648           0                     24                     0
# 1              428           0                     75                     0
# 2              648           6                     56                     0
# 3              892           3                     53                     1
# 4              648           7                     79                     1
# ...            ...         ...                    ...                   ...
# 66703          511           1                     28                     0
# 66704          328           1                     28                     0
# 66705          893           1                     28                     0
# 66706          820           1                     28                     0
# 66707          182           1                     37                     0
#
# ...

# %%
#Pre-Processed Non-Categorical Data Subset
df_non_cat_ppd = df_non_cat_mdt_mmn.copy(); df_non_cat_ppd # Preferred Data Subset
# Out:
#        Product_id  OriginalPrice (in Rs)  Ratings  Reviews  \
# 0         2296012                   1499      3.9      999
# 1        13780156                   1149      4.0      999
# 2        11895958                   1399      4.3      999
# 3         4335679                   1295      4.2      999
# 4        11690882                    599      4.2      999
# ...           ...                    ...      ...      ...
# 66703    13017776                   2999      4.6       33
# 66704    14604098                   3299      4.3       33
# 66705     7127587                   3398      3.8       33
# 66706    14051584                   3499      4.3       33
# 66707    10263333                   3590      3.8       33
#
#        DiscountPrice (in Rs)  DiscountOffer  OriginalPrice (in Rs)_mn  \
# 0                        317             32                  0.068945
# 1                        443             50                  0.051331
# ...

# %%
# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_non_cat_ppd); df_ppd # Pre-Processed Dataset
# Out:
#        BrandName_x  Category_x  Individual_category_x  category_by_Gender_x  \
# 0              648           0                     24                     0
# 1              428           0                     75                     0
# 2              648           6                     56                     0
# 3              892           3                     53                     1
# 4              648           7                     79                     1
# ...            ...         ...                    ...                   ...
# 66703          511           1                     28                     0
# 66704          328           1                     28                     0
# 66705          893           1                     28                     0
# 66706          820           1                     28                     0
# 66707          182           1                     37                     0
#
# ...

# %%
df_ppd = pd.merge(df_cat_ppd, df_non_cat_ppd, left_index=True, right_index=True)

# %%
df_ppd.head(5)
# Out:
#    BrandName_x  Category_x  Individual_category_x  category_by_Gender_x  \
# 0          648           0                     24                     0
# 1          428           0                     75                     0
# 2          648           6                     56                     0
# 3          892           3                     53                     1
# 4          648           7                     79                     1
#
#    Description_x  SizeOption_x  BrandName_y  Category_y  \
# 0          41046           131        648.0         0.0
# 1          28448           969        428.0         0.0
# 2          41089           810        648.0         6.0
# 3          58327           975        892.0         3.0
# 4          43301          1066        648.0         7.0
#
#    Individual_category_y  category_by_Gender_y  ...  OriginalPrice (in Rs)  \
# 0                   24.0                   0.0  ...                   1499
# ...

# %%
# prompt: drop the column which have mn in the end

df_ppd.drop(columns=[col for col in df_ppd.columns if col.endswith('mn')], inplace=True)

# %%
df_ppd.drop(columns=[col for col in df_ppd.columns if col.endswith('x')], inplace=True)

# %%
df_inputs = df_ppd[['BrandName_y', 'Category_y', 'Individual_category_y', 'Description_y', 'SizeOption_y', 'Product_id', 'OriginalPrice (in Rs)', 'Ratings', 'DiscountPrice (in Rs)','Reviews','DiscountOffer']]; df_inputs
# Out:
#        BrandName_y  Category_y  Individual_category_y  Description_y  \
# 0            648.0         0.0                   24.0        41046.0
# 1            428.0         0.0                   75.0        28448.0
# 2            648.0         6.0                   56.0        41089.0
# 3            892.0         3.0                   53.0        58327.0
# 4            648.0         7.0                   79.0        43301.0
# ...            ...         ...                    ...            ...
# 66703        511.0         1.0                   28.0        34412.0
# 66704        328.0         1.0                   28.0        19312.0
# 66705        893.0         1.0                   28.0        58533.0
# 66706        820.0         1.0                   28.0        54700.0
# 66707        182.0         1.0                   37.0         7845.0
#
#        SizeOption_y  Product_id  OriginalPrice (in Rs)  Ratings  \
# 0             131.0     2296012                   1499      3.9
# ...

# %%
df_outputs = df_ppd[['category_by_Gender_y']]; df_outputs
# Out:
#        category_by_Gender_y
# 0                       0.0
# 1                       0.0
# 2                       0.0
# 3                       1.0
# 4                       1.0
# ...                     ...
# 66703                   0.0
# 66704                   0.0
# 66705                   0.0
# 66706                   0.0
# 66707                   0.0
#
# [66708 rows x 1 columns]

# %%
df_inputs_names = df_inputs.columns; df_inputs_names
df_outputs_labels = df_outputs['category_by_Gender_y'].unique().astype(str); df_outputs_labels
# Out:
# array(['0.0', '1.0'], dtype='<U32')

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45016)

# Perform the stratified split to get training and testing indices
for i, j in stratified_split.split(df, df_outputs):
    train_df_inputs, test_df_inputs = df.iloc[i], df.iloc[j]
    train_df_outputs, test_df_outputs = df_outputs.iloc[i], df_outputs.iloc[j]

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45020,max_depth = 3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(df_inputs, df_outputs); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45020)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(df_inputs_names),); print(dtc_model_rules)
# Out:
# |--- Category_y <= 0.50
# |   |--- class: 0.0
# |--- Category_y >  0.50
# |   |--- Category_y <= 6.50
# |   |   |--- Category_y <= 5.50
# |   |   |   |--- class: 1.0
# |   |   |--- Category_y >  5.50
# |   |   |   |--- class: 0.0
# |   |--- Category_y >  6.50
# |   |   |--- class: 1.0

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': df_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 2)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                   feature  importance
# 1              Category_y         1.0
# 0             BrandName_y         0.0
# 2   Individual_category_y         0.0
# 3           Description_y         0.0
# 4            SizeOption_y         0.0
# 5              Product_id         0.0
# 6   OriginalPrice (in Rs)         0.0
# 7                 Ratings         0.0
# 8   DiscountPrice (in Rs)         0.0
# 9                 Reviews         0.0
# 10          DiscountOffer         0.0

# %%
# Decision Tree : Plot [Training Subset]
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=df_inputs_names, class_names=df_outputs_labels, rounded=True, filled=True, fontsize=8)
plt.show()

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_model_predict_test = dtc_model.predict(df_inputs); dtc_model_predict_test
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
# Decision Tree : Prediction Evaluation (Testing Subset)
dtc_predict_conf_mat = pd.DataFrame(confusion_matrix(df_outputs, dtc_model_predict_test));print(dtc_predict_conf_mat)
dtc_predict_perf = classification_report(df_outputs, dtc_model_predict_test);  print(dtc_predict_perf)

import time
import psutil

# Record start time
start_time = time.time()

# Record start memory usage
start_memory = psutil.Process().memory_info().rss / 1024 / 1024  # in MB

# Initialize DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion='gini', random_state=1234)

# Train the DecisionTreeClassifier on the training data
dtc_model = dtc.fit(df_inputs, df_outputs)

# Make predictions on the test set
y_pred_dtc = dtc_model.predict(df_inputs)

# Record end time
end_time = time.time()

# Record end memory usage
end_memory = psutil.Process().memory_info().rss / 1024 / 1024  # in MB

# Calculate time taken for training and prediction
execution_time = end_time - start_time

# Calculate memory usage increase
memory_increase = end_memory - start_memory

# Print time and memory statistics
print("Execution Time (seconds):", execution_time)
print("Memory Usage Before (MB):", start_memory)
print("Memory Usage After (MB):", end_memory)
print("Memory Usage Increase (MB):", memory_increase)
# Out:
#        0      1
# 0  16494   7852
# 1      0  42362
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.68      0.81     24346
#          1.0       0.84      1.00      0.92     42362
#
#     accuracy                           0.88     66708
#    macro avg       0.92      0.84      0.86     66708
# weighted avg       0.90      0.88      0.88     66708
#
# Execution Time (seconds): 0.46407151222229004
# Memory Usage Before (MB): 506.359375
# Memory Usage After (MB): 506.359375
# Memory Usage Increase (MB): 0.0

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_predict_conf_mat, annot=True, fmt='d', cmap='Paired')
# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
# Define your decision tree classifier with desired parameters
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45016)

# Perform 5-fold cross-validation
cv_scores = cross_val_score(dtc_cv, df_inputs, df_outputs.values.ravel(), cv=29)
print("Cross-Validation Scores:", cv_scores)
print("Average Cross-Validation Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.95480226 0.99521947 0.99565406 0.99608866 0.99565406 0.99782703
#  0.99608866 0.99695784 0.9973913  0.99173913 0.99826087 0.99478261
#  0.99478261 0.99434783 0.99434783 0.99565217 0.99478261 0.99695652
#  0.99304348 0.99478261 0.99130435 0.99434783 0.99347826 0.99173913
#  0.99478261 0.99217391 0.99043478 0.99086957 0.98913043]
# Average Cross-Validation Score: 0.9930145683351282

# %%
# Compute F1 score
f1 = f1_score(df_outputs,dtc_model_predict_test, average='macro')  # or 'weighted' for weighted F1 score
print("F1 Score:", f1)

# Weighted F1 score
weighted_f1 = f1_score(df_outputs, dtc_model_predict_test,average='weighted')
print("Weighted F1 Score:", weighted_f1)
# Out:
# F1 Score: 0.861460356536244
# Weighted F1 Score: 0.8759694223572684

# %% [markdown]
# Random Forest

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45016)

# %%
rf_classifier.fit(df_inputs, df_outputs['category_by_Gender_y'])
# Out:
# RandomForestClassifier(random_state=45016)

# %%
# prediction for testing data
rf_prediction = rf_classifier.predict(df_inputs)

# %%
# Train the Random Forest classifier
rf_classifier.fit(df_inputs, df_outputs['category_by_Gender_y'])

# Print feature importances
feature_importances = rf_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': df_inputs.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("Feature Importances:")
print(sorted_feature_importance_df)
# Out:
# Feature Importances:
#                   Feature  Importance
# 1              Category_y    0.476535
# 4            SizeOption_y    0.159635
# 2   Individual_category_y    0.141368
# 3           Description_y    0.082561
# 0             BrandName_y    0.063891
# 6   OriginalPrice (in Rs)    0.037545
# 5              Product_id    0.019583
# 9                 Reviews    0.006693
# 7                 Ratings    0.005260
# 8   DiscountPrice (in Rs)    0.003832
# 10          DiscountOffer    0.003099

# %%
# Testing Subset
predict_conf_mat = pd.DataFrame(confusion_matrix(df_outputs,rf_prediction));print(predict_conf_mat)
predict_perf = classification_report(df_outputs, rf_prediction);  print(predict_perf)
# Out:
#        0      1
# 0  24346      0
# 1      0  42362
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     24346
#          1.0       1.00      1.00      1.00     42362
#
#     accuracy                           1.00     66708
#    macro avg       1.00      1.00      1.00     66708
# weighted avg       1.00      1.00      1.00     66708

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(predict_conf_mat, annot=True, fmt='d', cmap='Paired')
# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
# Assuming rf is your trained Random Forest classifier
for i in range(3):
    tree = rf_classifier.estimators_[i]  # Assuming rf_classifier is your trained Random Forest model
    dot_data = export_graphviz(tree,
                               feature_names=df_inputs.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Perform cross-validation with 5 folds
cv_scores = cross_val_score(rf_classifier, df_inputs, df_outputs['category_by_Gender_y'], cv=5)

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", cv_scores.mean())
# Out:
# Cross-Validation Scores: [0.99527807 0.99625244 0.9972268  0.99400345 0.98815681]
# Mean CV Score: 0.9941835131203396

# %%
# Export and visualize the first three decision trees
for i in range(3):
    tree = rf_classifier.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=df_inputs.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Initialize a dictionary to store tree frequencies
tree_frequency = Counter()

# Loop through the trees and count their frequency
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_graphviz(tree, feature_names=df_inputs.columns,
                               filled=True, max_depth=2, impurity=False, proportion=True)
    tree_frequency[tree_str] += 1

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Plot the top three trees
for tree_str, frequency in top_trees:
    graph = graphviz.Source(tree_str)
    display(graph)
